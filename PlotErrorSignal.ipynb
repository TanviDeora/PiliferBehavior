# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Plot the three error signals

# %%
# save images in folder

folder = './dataFolder/errorSignal/polyFitMethod/'

# %%
## Method Ia - get the slope, compute the tangent at the base    
polyfit = pd.read_csv('./dataFolder/errorSignal/Polyfit_errorAngle.csv', header = None)

# %%
polyfit.head()
# Out:
#    0         1
# 0  0 -0.045910
# 1  1  0.060733
# 2  2 -0.032827
# 3  3 -0.086807
# 4  4 -0.201196

# %%
plt.plot(polyfit[0]*1/100, polyfit[1]*180/np.pi)
plt.xlabel('Time (s)')
plt.ylabel('Angle (deg)')
# Out:
# Text(0, 0.5, 'Angle (deg)')

# %%
Digitized = pd.read_csv('./dataFolder/errorSignal/Digitized_errorAngle.csv', header = None)

# %%
plt.plot(polyfit[0]*1/100, Digitized[1]*180/np.pi, color = '#ff7f0e')
plt.xlabel('Time (s)')
plt.ylabel('Angle (deg)')
# Out:
# Text(0, 0.5, 'Angle (deg)')

# %%
plt.plot(polyfit[0]*1/100, Digitized[1]*180/np.pi)
plt.plot(polyfit[0]*1/100, polyfit[1]*180/np.pi)
plt.xlabel('Time (s)')
plt.ylabel('Angle (deg)')
plt.xlim([4, 5])
# Out:
# (4.0, 5.0)
